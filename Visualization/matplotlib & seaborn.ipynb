# %% [markdown]
# <a href="https://colab.research.google.com/github/Rojinar8/Machine-Learning/blob/main/Visualization/matplotlib%20%26%20seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Visualization with Matplotlib**

# %%
 import matplotlib.pyplot as plt
 import numpy as np
 import pandas as pd

# %%
#Basics of Matplotlib
#Line plot
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y)

# %%
x =np.linspace(0,10,100)
y =np.sin(x)
plt.plot(x, y, label="Sine wave")
plt.title("Line plot example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()

# %%
# Bar Chart
Categories =['A','B','C','D']
values=[10,20,30,40]
plt.bar(Categories,values,color=['olive','red','black','blue'])
plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("values")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## **Visualization with Seaborn**

# %%
import seaborn as sns

# %%
#Histogram and KDE plot:
data=np.random.randn(1000)
sns.histplot(data,kde=True, color='orange')
plt.title("Histogram with KDE")
plt.show()

# %%
#Heatmap
matrix= np.random.rand(5,5)
matrix
# Out:
# array([[0.59375281, 0.51284217, 0.32890114, 0.90623925, 0.38139205],
#        [0.77406469, 0.64646573, 0.64834127, 0.0133067 , 0.43109885],
#        [0.13749435, 0.96298657, 0.97407543, 0.32259029, 0.60235009],
#        [0.75329442, 0.54385065, 0.95804649, 0.31350206, 0.38515319],
#        [0.01050625, 0.38320225, 0.65734996, 0.67278403, 0.65807633]])

# %%
sns.heatmap(matrix,annot=True,cmap="magma")
plt.title("Heatmap Example")
plt.show()

# %%
#pairplot example
sns.set_style("whitegrid")
df=sns.load_dataset("iris")
sns.pairplot(df,hue="species",markers=["o","s","D"])
plt.show()
